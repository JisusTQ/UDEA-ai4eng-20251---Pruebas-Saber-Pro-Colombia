# %% [markdown]
# <a href="https://colab.research.google.com/github/JisusTQ/UDEA-ai4eng-20251---Pruebas-Saber-Pro-Colombia/blob/main/01%20-%20exploraci%C3%B3n.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #**UDEA/ai4eng 20251 - Pruebas Saber Pro Colombia**

# %% [markdown]
# #Cargamos los datos de `train.csv`

# %%
import pandas as pd
import numpy as np

z = pd.read_csv("train.csv")
print ("Se cargaron los datos correctamente", z.shape)
# Out:
# Se cargaron los datos correctamente (692500, 21)

# %%
# !pip install rlxutils

# %% [markdown]
# #Hacemos una primera exploración viendo los primero y últimos 10 datos

# %%
z.head(10)
# Out:
#        ID  PERIODO                  ESTU_PRGM_ACADEMICO  \
# 0  904256    20212                           ENFERMERIA
# 1  645256    20212                              DERECHO
# 2  308367    20203                MERCADEO Y PUBLICIDAD
# 3  470353    20195           ADMINISTRACION DE EMPRESAS
# 4  989032    20212                           PSICOLOGIA
# 5  659872    20203                 MEDICINA VETERINARIA
# 6   47159    20183                  INGENIERIA MECANICA
# 7   11829    20183  ADMINISTRACIÓN EN SALUD OCUPACIONAL
# 8  257869    20212                INGENIERIA INDUSTRIAL
# 9  465511    20183           ADMINISTRACION DE EMPRESAS
#
#   ESTU_PRGM_DEPARTAMENTO            ESTU_VALORMATRICULAUNIVERSIDAD  \
# 0                 BOGOTÁ  Entre 5.5 millones y menos de 7 millones
# 1              ATLANTICO  Entre 2.5 millones y menos de 4 millones
# 2                 BOGOTÁ  Entre 2.5 millones y menos de 4 millones
# 3              SANTANDER  Entre 4 millones y menos de 5.5 millones
# ...

# %%
z.tail(10)
# Out:
#             ID  PERIODO                                ESTU_PRGM_ACADEMICO  \
# 692490  403947    20195                                         PSICOLOGIA
# 692491  157529    20212               LICENCIATURA EN EDUCACION PREESCOLAR
# 692492  584597    20183     LICENCIATURA EN LENGUA CASTELLANA Y LITERATURA
# 692493  725949    20203                                            DERECHO
# 692494  649690    20212  LICENCIATURA EN EDUCACION BASICA CON ENFASIS E...
# 692495   25096    20195                                           BIOLOGIA
# 692496  754213    20212                                         PSICOLOGIA
# 692497  504185    20183                ADMINISTRACIÓN EN SALUD OCUPACIONAL
# 692498  986620    20195                                         PSICOLOGIA
# 692499  933374    20195                                         PSICOLOGIA
#
#        ESTU_PRGM_DEPARTAMENTO            ESTU_VALORMATRICULAUNIVERSIDAD  \
# ...

# %% [markdown]
# #Realizamos un filtro de los primeros diez datos de `ESTU_PRGM_DEPARTAMENTO` , `FAMI_ESTRATOVIVIENDA` , `ESTU_VALORMATRICULAUNIVERSIDAD` y `RENDIMIENTO_GLOBAL`

# %%
z = z[['ESTU_PRGM_DEPARTAMENTO','FAMI_ESTRATOVIVIENDA', 'ESTU_VALORMATRICULAUNIVERSIDAD', 'RENDIMIENTO_GLOBAL']]
z.head(10)
# Out:
#   ESTU_PRGM_DEPARTAMENTO FAMI_ESTRATOVIVIENDA  \
# 0                 BOGOTÁ            Estrato 3
# 1              ATLANTICO            Estrato 3
# 2                 BOGOTÁ            Estrato 3
# 3              SANTANDER            Estrato 4
# 4              ANTIOQUIA            Estrato 3
# 5              ANTIOQUIA            Estrato 5
# 6                  HUILA            Estrato 2
# 7                 BOGOTÁ            Estrato 2
# 8              ATLANTICO            Estrato 1
# 9              ANTIOQUIA            Estrato 5
#
#              ESTU_VALORMATRICULAUNIVERSIDAD RENDIMIENTO_GLOBAL
# 0  Entre 5.5 millones y menos de 7 millones         medio-alto
# 1  Entre 2.5 millones y menos de 4 millones               bajo
# 2  Entre 2.5 millones y menos de 4 millones               bajo
# 3  Entre 4 millones y menos de 5.5 millones               alto
# 4  Entre 2.5 millones y menos de 4 millones         medio-bajo
# 5                         Más de 7 millones         medio-alto
# ...

# %% [markdown]
# #Miramos datos específicos en dos diagramas distintos para `FAMI_ESTRATOVIVIENDA`.

# %%
z.FAMI_ESTRATOVIVIENDA.value_counts().plot(kind='pie')
# Out:
# <Axes: ylabel='count'>

# %%
z.FAMI_ESTRATOVIVIENDA.value_counts().plot(kind='barh')
# Out:
# <Axes: ylabel='FAMI_ESTRATOVIVIENDA'>

# %% [markdown]
# #Utilizamos librerías adicionales para comparar dos datos en específico

# %% [markdown]
# Comparación Rendimiento Global de los estudiantes con respecto a su estrato socioeconómico.

# %%
from rlxutils import subplots
import matplotlib.pyplot as plt

c = sorted(z.FAMI_ESTRATOVIVIENDA.value_counts().index)
for ax,ci in subplots(c, n_cols=4, usizex=4):
    zc = z[z.FAMI_ESTRATOVIVIENDA==ci]
    zc.RENDIMIENTO_GLOBAL.value_counts()[['bajo', 'medio-bajo', 'medio-alto', 'alto']].plot(kind='bar')
    plt.title(ci)

# %% [markdown]
# Comparación de la cantidad de estudiantes por Departamento (SANDANTER, ANTIOQUIA, ATLANTICO y LA GUAJIRA) con respecto a su estrato socioeconómico.

# %%
c = sorted(z.FAMI_ESTRATOVIVIENDA.value_counts().index)
for ax,ci in subplots(c, n_cols=4, usizex=4):
    zc = z[z.FAMI_ESTRATOVIVIENDA==ci]
    zc.	ESTU_PRGM_DEPARTAMENTO.value_counts()[['SANTANDER', 'ANTIOQUIA', 'ATLANTICO', 'LA GUAJIRA']].plot(kind='bar')
    plt.title(ci)
